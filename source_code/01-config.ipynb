# %%
# catalog name for Unity catalog
catalog = "tfl_pipeline"

# Schema references for each layer in the lakehouse
landing_zone = "0_landing"
schema_landing = f"{catalog}.{landing_zone}"

schema_bronze = f"{catalog}.1_bronze_db"
schema_silver = f"{catalog}.2_silver_db"
schema_gold = f"{catalog}.3_gold_db"

# Volume references within the landing schema
raw_volume = f"{schema_landing}.raw"
checkpoint_volume = f"{schema_landing}.checkpoints"
test_volume = f"{schema_landing}.test_data"

# Base paths for each volume in Databricks
raw_base_path  = f"/Volumes/{catalog}/{landing_zone}/raw"
checkpoint_base_path = f"/Volumes/{catalog}/{landing_zone}/checkpoints"
test_base_path = f"/Volumes/{catalog}/{landing_zone}/test_data"

# Subfolder paths within the raw volume for different data domains
source_subdir = {
    "arrivals": f"{raw_base_path}/arrivals",
    "line_status": f"{raw_base_path}/line_status",
    "stop_points": f"{raw_base_path}/stop_points",
    "london_boroughs": f"{raw_base_path}/london_boroughs",
}
